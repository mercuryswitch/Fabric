# %% [markdown]
# **Define Path to file to be validated**

# %%
%pip install great_expectations
# Out:
# StatementMeta(, 7050b7e8-5ec1-4ffb-b326-481de92baa7a, 10, Finished, Available)
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
#path to file to be validated as a parameter cell >

file_path_to_be_validated = '/Files/ESP_Construction_Services.csv'
output_table_name = 'raw_construction'

display(file_path_to_be_validated)
# Out:
# StatementMeta(, 7050b7e8-5ec1-4ffb-b326-481de92baa7a, 12, Finished, Available)
# '/Files/ESP_Construction_Services.csv'

# %% [markdown]
# **Installs great expectations**

# %%
file_path_to_be_validated = spark.read.format("csv").option("header","true").load("Files/ESP_Construction_Services.csv")
# file_path_etc now is a Spark DataFrame containing CSV data from "Files/ESP_Construction_Services.csv".

# %% [markdown]
# **Import Pandas and GE**

# %%
import pandas as pd 

import great_expectations as gx

context = gx.get_context()

validator = context.sources.pandas_default.read_csv(file_path_to_be_validated)
# Out:
# StatementMeta(, 87813114-8083-48a1-b79a-0515a9a61969, 4, Finished, Available)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 3
#       1 import pandas as pd
# ----> 3 import great_expectations as gx
#       5 context = gx.get_context()
#       7 validator = context.sources.pandas_default.read_csv(file_path_to_be_validated)
#
# ModuleNotFoundError: No module named 'great_expectations'
